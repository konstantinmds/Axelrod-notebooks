# %% [markdown]
# This notebook shows how to build a probabilistic ending tournament. The documentation for this can be found here: ...

# %%
import axelrod as axl
import random  # To set a seed
# %matplotlib inline

# %%
random.seed(1) 
strategies = [axl.Cooperator(), axl.Defector(),
              axl.TitForTat(), axl.Grudger()]
tournament = axl.ProbEndTournament(strategies, prob_end=.5)
results = tournament.play()
plot = axl.Plot(results)
plot.boxplot();

# %%
eco = axl.Ecosystem(results)
eco.reproduce(100)
plot.stackplot(eco);

# %%
random.seed(1) 
strategies = [axl.Cooperator(), axl.Defector(),
              axl.TitForTat(), axl.Grudger()]
tournament = axl.ProbEndTournament(strategies, prob_end=.01)
results = tournament.play()
plot = axl.Plot(results)
plot.boxplot();

# %%
eco = axl.Ecosystem(results)
eco.reproduce(100)
plot.stackplot(eco);
