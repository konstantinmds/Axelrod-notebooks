# %% [markdown]
# This notebook shows how to build a probabilistic ending tournament. The documentation for this can be found here: ...

# %%
import axelrod as axl
import random  # To set a seed
import seaborn
# %matplotlib inline
# Out:
# /usr/local/lib/python3.4/dist-packages/matplotlib/backends/backend_gtk3agg.py:18: UserWarning: The Gtk3Agg backend is known to not work on Python 3.x with pycairo. Try installing cairocffi.
#   "The Gtk3Agg backend is known to not work on Python 3.x with pycairo. "
# /usr/local/lib/python3.4/dist-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
random.seed(1)
reps = 3000
strategies = [axl.Cooperator(), axl.Defector(),
              axl.TitForTat(), axl.Grudger()]
tournament = axl.ProbEndTournament(strategies, prob_end=.5, repetitions=reps)
results = tournament.play()
plot = axl.Plot(results)
plot.boxplot();

# %%
eco = axl.Ecosystem(results)
eco.reproduce(100)
plot.stackplot(eco);

# %%
random.seed(1) 
strategies = [axl.Cooperator(), axl.Defector(),
              axl.TitForTat(), axl.Grudger()]
tournament = axl.ProbEndTournament(strategies, prob_end=.01)
results = tournament.play()
plot = axl.Plot(results)
plot.boxplot();

# %%
eco = axl.Ecosystem(results)
eco.reproduce(100)
plot.stackplot(eco);

# %%
plot.payoff();

# %%
plot.lengthplot();
